# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine
#import config

# %%
#Extract CSV into DataFrame
data_analyst_df = pd.read_csv("../data/clean_data_analyst.csv")
data_analyst_df
# Out:
#         ID                                              Title  \
# 0        0  Data Analyst, Center on Immigration and Justic...
# 1        1                               Quality Data Analyst
# 2        2  Senior Data Analyst, Insights & Analytics Team...
# 3        3                                       Data Analyst
# 4        4                             Reporting Data Analyst
# ...    ...                                                ...
# 2248  2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249  2249              Senior Data Analyst (Corporate Audit)
# 2250  2250  Technical Business Analyst (SQL, Data analytic...
# 2251  2251                Data Analyst 3, Customer Experience
# 2252  2252                        Senior Quality Data Analyst
#
#                            Salary  Rating                             Company  \
# 0      $37K-$66K (Glassdoor est.)     3.2           Vera Institute of Justice
# 1      $37K-$66K (Glassdoor est.)     3.8  Visiting Nurse Service of New York
# 2      $37K-$66K (Glassdoor est.)     3.4                         Squarespace
# 3      $37K-$66K (Glassdoor est.)     4.1                            Celerity
# 4      $37K-$66K (Glassdoor est.)     3.9                             FanDuel
# ...                           ...     ...                                 ...
# 2248  $78K-$104K (Glassdoor est.)     2.5                       Avacend, Inc.
# 2249  $78K-$104K (Glassdoor est.)     2.9                   Arrow Electronics
# 2250  $78K-$104K (Glassdoor est.)     NaN                            Spiceorb
# 2251  $78K-$104K (Glassdoor est.)     3.1         Contingent Network Services
# 2252  $78K-$104K (Glassdoor est.)     3.4                          SCL Health
#
#             Location      Headquarters                    Size  Founded  \
# 0       New York, NY      New York, NY    201 to 500 employees   1961.0
# 1       New York, NY      New York, NY        10000+ employees   1893.0
# 2       New York, NY      New York, NY  1001 to 5000 employees   2003.0
# 3       New York, NY        McLean, VA    201 to 500 employees   2002.0
# 4       New York, NY      New York, NY   501 to 1000 employees   2009.0
# ...              ...               ...                     ...      ...
# 2248      Denver, CO    Alpharetta, GA     51 to 200 employees      NaN
# 2249  Centennial, CO    Centennial, CO        10000+ employees   1935.0
# 2250      Denver, CO               NaN                     NaN      NaN
# 2251  Centennial, CO  West Chester, OH    201 to 500 employees   1984.0
# 2252  Broomfield, CO    Broomfield, CO        10000+ employees   1864.0
#
#                            ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                             NaN                                      NaN
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue   min  \
# 0                           Non-Profit  $100 to $500 million (USD)  $37K
# 1                          Health Care      $2 to $5 billion (USD)  $37K
# 2               Information Technology    Unknown / Non-Applicable  $37K
# 3               Information Technology   $50 to $100 million (USD)  $37K
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)  $37K
# ...                                ...                         ...   ...
# 2248                 Business Services    Unknown / Non-Applicable  $78K
# 2249                 Business Services          $10+ billion (USD)  $78K
# 2250                               NaN                         NaN  $78K
# 2251            Information Technology    $25 to $50 million (USD)  $78K
# 2252                       Health Care      $2 to $5 billion (USD)  $78K
#
#         max
# 0      $66K
# 1      $66K
# 2      $66K
# 3      $66K
# 4      $66K
# ...     ...
# 2248  $104K
# 2249  $104K
# 2250  $104K
# 2251  $104K
# 2252  $104K
#
# [2253 rows x 15 columns]

# %%
#Create Database connection
connection_string = "postgres:postgres@localhost:5432/data_analyst_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# <ipython-input-4-2d97e9123e98>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['analyst', 'data_analyst']

# %%
#Use pandas to Load  csv converted DataFrames into database
data_analyst_df.to_sql(name='data_analyst', con=engine, if_exists='append', index=False)

# %%
#confirm data has been added by quering the table
pd.read_sql_query('select * from data_analyst', con=engine).head()
# Out:
#    ID                                              Title  \
# 0   0  Data Analyst, Center on Immigration and Justic...
# 1   1                               Quality Data Analyst
# 2   2  Senior Data Analyst, Insights & Analytics Team...
# 3   3                                       Data Analyst
# 4   4                             Reporting Data Analyst
#
#                        Salary  Rating                             Company  \
# 0  $37K-$66K (Glassdoor est.)     3.2           Vera Institute of Justice
# 1  $37K-$66K (Glassdoor est.)     3.8  Visiting Nurse Service of New York
# 2  $37K-$66K (Glassdoor est.)     3.4                         Squarespace
# 3  $37K-$66K (Glassdoor est.)     4.1                            Celerity
# 4  $37K-$66K (Glassdoor est.)     3.9                             FanDuel
#
#        Location  Headquarters                    Size  Founded  \
# 0  New York, NY  New York, NY    201 to 500 employees   1961.0
# 1  New York, NY  New York, NY        10000+ employees   1893.0
# 2  New York, NY  New York, NY  1001 to 5000 employees   2003.0
# 3  New York, NY    McLean, VA    201 to 500 employees   2002.0
# 4  New York, NY  New York, NY   501 to 1000 employees   2009.0
#
#                         ownership                          Industry  \
# 0          Nonprofit Organization                 Social Assistance
# 1          Nonprofit Organization  Health Care Services & Hospitals
# 2               Company - Private                          Internet
# 3  Subsidiary or Business Segment                       IT Services
# 4               Company - Private               Sports & Recreation
#
#                              Sector                     Revenue   min   max
# 0                        Non-Profit  $100 to $500 million (USD)  $37K  $66K
# 1                       Health Care      $2 to $5 billion (USD)  $37K  $66K
# 2            Information Technology    Unknown / Non-Applicable  $37K  $66K
# 3            Information Technology   $50 to $100 million (USD)  $37K  $66K
# 4  Arts, Entertainment & Recreation  $100 to $500 million (USD)  $37K  $66K
