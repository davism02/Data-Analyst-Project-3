# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
import pandas as pd
import json
import decimal

# %%
connection_string = "postgres:Jpm!1990@localhost:5432/da_job"
engine = create_engine(f'postgresql://{connection_string}')
engine.table_names()
Base=automap_base()
Base.prepare(engine,reflect=True)
Base.classes.keys()
# Out:
# <ipython-input-19-2ded1b531a97>:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['data_analyst', 'data_analyst_testing']

# %%
table=Base.classes.data_analyst_testing
session=Session(engine)

# %%
session.query(table.id,table.Title,table.Salary,table.Rating,table.Company,table.Headquarters,table.Size,table.ownership,table.Industry,table.Sector,table.Revenue,table.min,table.max).all()
# Out:
# [(0, 'Data Analyst, Center on Immigration and Justice (CIJ)', '$37K-$66K (Glassdoor est.)', '3.2', 'Vera Institute of Justice', 'New York, NY', '201 to 500 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$100 to $500 million (USD)', 37000.0, 66000),
#  (1, 'Quality Data Analyst', '$37K-$66K (Glassdoor est.)', '3.8', 'Visiting Nurse Service of New York', 'New York, NY', '10000+ employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$2 to $5 billion (USD)', 37000.0, 66000),
#  (2, 'Senior Data Analyst, Insights & Analytics Team [Customer Operations]', '$37K-$66K (Glassdoor est.)', '3.4', 'Squarespace', 'New York, NY', '1001 to 5000 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (3, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '4.1', 'Celerity', 'McLean, VA', '201 to 500 employees', 'Subsidiary or Business Segment', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 37000.0, 66000),
#  (4, 'Reporting Data Analyst', '$37K-$66K (Glassdoor est.)', '3.9', 'FanDuel', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Sports & Recreation', 'Arts, Entertainment & Recreation', '$100 to $500 million (USD)', 37000.0, 66000),
#  (5, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '3.9', 'Point72', 'Stamford, CT', '1001 to 5000 employees', 'Company - Private', 'Investment Banking & Asset Management', 'Finance', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (6, 'Business/Data Analyst (FP&A)', '$37K-$66K (Glassdoor est.)', '4.4', 'Two Sigma', 'New York, NY', '1001 to 5000 employees', 'Company - Private', 'Investment Banking & Asset Management', 'Finance', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (7, 'Data Science Analyst', '$37K-$66K (Glassdoor est.)', '3.7', 'GNY Insurance Companies', 'New York, NY', '201 to 500 employees', 'Company - Private', 'Insurance Carriers', 'Insurance', '$100 to $500 million (USD)', 37000.0, 66000),
#  (8, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '4.0', 'DMGT', 'London, United Kingdom', '5001 to 10000 employees', 'Company - Public', 'Venture Capital & Private Equity', 'Finance', '$1 to $2 billion (USD)', 37000.0, 66000),
#  (9, 'Data Analyst, Merchant Health', '$37K-$66K (Glassdoor est.)', '4.4', 'Riskified', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Research & Development', 'Business Services', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (10, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '4.0', 'NYU Langone Health', 'New York, NY', '10000+ employees', 'Hospital', 'Health Care Services & Hospitals', 'Health Care', '$5 to $10 billion (USD)', 37000.0, 66000),
#  (12, 'DATA ANALYST', '$37K-$66K (Glassdoor est.)', '3.7', 'Montefiore Medical', 'Bronx, NY', '10000+ employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$2 to $5 billion (USD)', 37000.0, 66000),
#  (13, 'Senior Data Analyst', '$37K-$66K (Glassdoor est.)', '3.0', 'Known', 'New York, NY', '201 to 500 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', '$100 to $500 million (USD)', 37000.0, 66000),
#  (14, 'Investment Advisory Data Analyst', '$37K-$66K (Glassdoor est.)', '3.4', 'Advisor Group', 'Phoenix, AZ', '1001 to 5000 employees', 'Company - Private', 'Brokerage Services', 'Finance', '$1 to $5 million (USD)', 37000.0, 66000),
#  (15, 'Sustainability Data Analyst', '$37K-$66K (Glassdoor est.)', '3.6', 'CodeGreen Solutions', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Building & Personnel Services', 'Business Services', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (16, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '3.8', 'Undertone', 'New York, NY', '201 to 500 employees', 'Subsidiary or Business Segment', 'Advertising & Marketing', 'Business Services', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (17, 'Clinical Data Analyst', '$37K-$66K (Glassdoor est.)', '3.8', 'NYSTEC', 'Rome, NY', '51 to 200 employees', 'Nonprofit Organization', 'Consulting', 'Business Services', '$25 to $50 million (USD)', 37000.0, 66000),
#  (18, 'DATA PROGRAMMER/ANALYST', '$37K-$66K (Glassdoor est.)', '3.9', 'Education Development Center, Inc.', 'Waltham, MA', '501 to 1000 employees', 'Nonprofit Organization', 'Research & Development', 'Business Services', '$100 to $500 million (USD)', 37000.0, 66000),
#  (19, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '4.9', 'Teachers Pay Teachers', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (20, 'Product Analyst, Data Science', '$37K-$66K (Glassdoor est.)', '4.4', 'Google', 'Mountain View, CA', '10000+ employees', 'Company - Public', 'Internet', 'Information Technology', '$10+ billion (USD)', 37000.0, 66000),
#  (22, 'Data Analyst - Intex Developer', '$37K-$66K (Glassdoor est.)', '3.3', 'Macquarie Group', 'Sydney, Australia', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$5 to $10 billion (USD)', 37000.0, 66000),
#  (23, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '3.5', 'Andiamo', 'Warren, MI', '201 to 500 employees', 'Company - Private', 'Casual Restaurants', 'Restaurants, Bars & Food Services', '$1 to $5 million (USD)', 37000.0, 66000),
#  (25, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '4.0', 'Hearst Communications', 'San Francisco, CA', '1 to 50 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', 'Less than $1 million (USD)', 37000.0, 66000),
#  (26, 'Data + Business Intelligence Analyst', '$37K-$66K (Glassdoor est.)', '5.0', 'Duolingo', 'Pittsburgh, PA', '201 to 500 employees', 'Company - Private', 'Internet', 'Information Technology', '$10 to $25 million (USD)', 37000.0, 66000),
#  (27, 'Data Analyst, Product', '$37K-$66K (Glassdoor est.)', '4.8', 'Ro', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Health Care Services & Hospitals', 'Health Care', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (28, 'Data Analyst Entry Level', '$37K-$66K (Glassdoor est.)', '3.7', 'Endai', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', '$1 to $5 million (USD)', 37000.0, 66000),
#  (29, 'Data Analyst', '$37K-$66K (Glassdoor est.)', '4.7', 'BlueLabs', 'Washington, DC', '1 to 50 employees', 'Company - Private', 'Research & Development', 'Business Services', 'Unknown / Non-Applicable', 37000.0, 66000),
#  (30, 'Data Analyst', '$46K-$87K (Glassdoor est.)', '3.6', 'Revel', 'Seattle, WA', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$25 to $50 million (USD)', 46000.0, 87000),
#  (31, 'Data Analyst', '$46K-$87K (Glassdoor est.)', '3.6', 'NALLAS CORPORATION', 'Newtown, PA', '1 to 50 employees', 'Company - Private', 'Enterprise Software & Network Solutions', 'Information Technology', '$1 to $5 million (USD)', 46000.0, 87000),
#  (33, 'Data Science Analyst, Capital Markets', '$46K-$87K (Glassdoor est.)', '3.2', 'SoFi', 'San Francisco, CA', '1001 to 5000 employees', 'Company - Private', 'Lending', 'Finance', 'Unknown / Non-Applicable', 46000.0, 87000),
#  (35, 'Analyst/Associate Global Markets Credit Data Analyst', '$46K-$87K (Glassdoor est.)', '3.7', 'Bank of America', 'Charlotte, NC', '10000+ employees', 'Company - Public', 'Banks & Credit Unions', 'Finance', '$10+ billion (USD)', 46000.0, 87000),
#  (37, 'Data Analyst with Excel/DAX/ PowerBI experience- Fulltime', '$46K-$87K (Glassdoor est.)', '3.6', 'Nutech Information Systems', 'Westmont, IL', '1 to 50 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', 'Less than $1 million (USD)', 46000.0, 87000),
#  (38, 'Data Science Analyst/Engineer', '$46K-$87K (Glassdoor est.)', '4.0', 'NYU Langone Health', 'New York, NY', '10000+ employees', 'Hospital', 'Health Care Services & Hospitals', 'Health Care', '$5 to $10 billion (USD)', 46000.0, 87000),
#  (39, 'Data Analyst', '$46K-$87K (Glassdoor est.)', '4.6', 'The Trevor Project', 'West Hollywood, CA', '51 to 200 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$10 to $25 million (USD)', 46000.0, 87000),
#  (43, 'Data Analyst -1+ year Contract - NYC', '$46K-$87K (Glassdoor est.)', '4.0', 'Two95 International Inc.', 'Cherry Hill, NJ', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$1 to $5 million (USD)', 46000.0, 87000),
#  (44, 'Data Analyst', '$46K-$87K (Glassdoor est.)', '3.0', 'Vettery', 'New York, NY', '201 to 500 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 46000.0, 87000),
#  (45, 'Data Analyst', '$46K-$87K (Glassdoor est.)', '2.9', 'Nesco Resource, LLC', 'Cleveland, OH', '1001 to 5000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$500 million to $1 billion (USD)', 46000.0, 87000),
#  (46, 'Advertising Data Analyst', '$46K-$87K (Glassdoor est.)', '4.0', 'Hearst Communications', 'San Francisco, CA', '1 to 50 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', 'Less than $1 million (USD)', 46000.0, 87000),
#  (47, 'Data Analyst', '$46K-$87K (Glassdoor est.)', '3.6', 'MediaMath', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', '$100 to $500 million (USD)', 46000.0, 87000),
#  (48, 'Market Data Reporting Analyst', '$46K-$87K (Glassdoor est.)', '4.9', 'Jordan & Jordan', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Brokerage Services', 'Finance', 'Unknown / Non-Applicable', 46000.0, 87000),
#  (49, 'Senior Analyst, Data Science', '$46K-$87K (Glassdoor est.)', '3.9', 'Roku', 'San Jose, CA', '1001 to 5000 employees', 'Company - Public', 'IT Services', 'Information Technology', '$500 million to $1 billion (USD)', 46000.0, 87000),
#  (50, 'Senior Data Analyst, Disney+', '$46K-$87K (Glassdoor est.)', '4.0', 'Walt Disney Co.', 'Burbank, CA', '10000+ employees', 'Company - Public', 'Motion Picture Production & Distribution', 'Media', '$10+ billion (USD)', 46000.0, 87000),
#  (52, 'Business Data Analyst', '$46K-$87K (Glassdoor est.)', '3.7', 'Xoriant Corporation', 'Sunnyvale, CA', '1001 to 5000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 46000.0, 87000),
#  (53, 'Senior Data Analyst', '$46K-$87K (Glassdoor est.)', '3.6', 'Gemini', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Brokerage Services', 'Finance', 'Unknown / Non-Applicable', 46000.0, 87000),
#  (54, 'Data Scientist / Big Data Analytics Analyst', '$46K-$87K (Glassdoor est.)', '3.6', 'TSR, Inc.', 'Hauppauge, NY', '201 to 500 employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$50 to $100 million (USD)', 46000.0, 87000),
#  (56, 'Principal Data Analyst, LATAM - Disney Streaming Services', '$46K-$87K (Glassdoor est.)', '4.0', 'Walt Disney Co.', 'Burbank, CA', '10000+ employees', 'Company - Public', 'Motion Picture Production & Distribution', 'Media', '$10+ billion (USD)', 46000.0, 87000),
#  (57, 'Data Analyst II', '$46K-$87K (Glassdoor est.)', '3.2', 'Fragomen Worldwide', 'New York, NY', '1001 to 5000 employees', 'Company - Private', 'Legal', 'Accounting & Legal', '$500 million to $1 billion (USD)', 46000.0, 87000),
#  (58, 'Data Analyst - Environmental, Social, and Governance', '$46K-$87K (Glassdoor est.)', '3.8', 'Bloomberg', 'New York, NY', '10000+ employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', 'Unknown / Non-Applicable', 46000.0, 87000),
#  (59, 'Data Analyst', '$46K-$87K (Glassdoor est.)', '3.9', 'Real Capital Analytics', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Real Estate', 'Real Estate', '$25 to $50 million (USD)', 46000.0, 87000),
#  (60, 'Data Analyst, Revenue Analytics', '$51K-$88K (Glassdoor est.)', '4.8', 'Ro', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Health Care Services & Hospitals', 'Health Care', 'Unknown / Non-Applicable', 51000.0, 88000),
#  (61, 'Data Analyst - Data Acquisition / Data Lineage', '$51K-$88K (Glassdoor est.)', '3.6', 'Perficient', 'Saint Louis, MO', '1001 to 5000 employees', 'Company - Public', 'IT Services', 'Information Technology', '$500 million to $1 billion (USD)', 51000.0, 88000),
#  (62, 'Data Analyst - Data Scanning utilizing Rochade', '$51K-$88K (Glassdoor est.)', '3.6', 'Perficient', 'Saint Louis, MO', '1001 to 5000 employees', 'Company - Public', 'IT Services', 'Information Technology', '$500 million to $1 billion (USD)', 51000.0, 88000),
#  (63, 'Data Analyst - Stitching', '$51K-$88K (Glassdoor est.)', '3.6', 'Perficient', 'Saint Louis, MO', '1001 to 5000 employees', 'Company - Public', 'IT Services', 'Information Technology', '$500 million to $1 billion (USD)', 51000.0, 88000),
#  (64, 'Junior Data Analyst', '$51K-$88K (Glassdoor est.)', '4.1', 'Kforce', 'Tampa, FL', '10000+ employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$1 to $2 billion (USD)', 51000.0, 88000),
#  (65, 'Data Analyst, Retail Media', '$51K-$88K (Glassdoor est.)', '3.9', 'Criteo', 'Paris, France', '1001 to 5000 employees', 'Company - Public', 'Internet', 'Information Technology', '$2 to $5 billion (USD)', 51000.0, 88000),
#  (66, 'Data Analyst', '$51K-$88K (Glassdoor est.)', '3.0', 'Royal Communications', 'New York, NY', '1 to 50 employees', 'Company - Private', 'IT Services', 'Information Technology', '$1 to $5 million (USD)', 51000.0, 88000),
#  (67, 'Portfolio Data Analyst', '$51K-$88K (Glassdoor est.)', '3.7', 'Neuberger Berman', 'New York, NY', '1001 to 5000 employees', 'Company - Private', 'Investment Banking & Asset Management', 'Finance', '$500 million to $1 billion (USD)', 51000.0, 88000),
#  (69, 'Data/Reporting Analyst', '$51K-$88K (Glassdoor est.)', '3.9', 'Diverse Lynx', 'Princeton, NJ', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 51000.0, 88000),
#  (70, 'Data Analyst 2', '$51K-$88K (Glassdoor est.)', '3.7', 'eTeam Inc.', 'South Plainfield, NJ', '51 to 200 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$50 to $100 million (USD)', 51000.0, 88000),
#  (73, 'Data/Information Mgt Analyst', '$51K-$88K (Glassdoor est.)', '3.7', 'Citi', 'New York, NY', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 51000.0, 88000),
#  (74, 'Business Data Analyst', '$51K-$88K (Glassdoor est.)', '3.6', 'Axelon Services Corporation', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$100 to $500 million (USD)', 51000.0, 88000),
#  (75, 'Information Systems Officer (Data Analyst)', '$51K-$88K (Glassdoor est.)', '4.1', 'United Nations', 'New York, NY', '10000+ employees', 'Government', 'Federal Agencies', 'Government', 'Unknown / Non-Applicable', 51000.0, 88000),
#  (76, 'Media Science Big Data Analyst', '$51K-$88K (Glassdoor est.)', '3.5', 'Discovery Communications, Inc.', 'New York, NY', '10000+ employees', 'Company - Public', 'TV Broadcast & Cable Networks', 'Media', '$5 to $10 billion (USD)', 51000.0, 88000),
#  (77, 'Data Analyst', '$51K-$88K (Glassdoor est.)', '3.7', 'Randstad', 'Atlanta, GA', '1001 to 5000 employees', 'Subsidiary or Business Segment', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 51000.0, 88000),
#  (79, 'Data analyst with Python', '$51K-$88K (Glassdoor est.)', '4.0', 'Two95 International Inc.', 'Cherry Hill, NJ', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$1 to $5 million (USD)', 51000.0, 88000),
#  (81, 'Data Analyst', '$51K-$88K (Glassdoor est.)', '5.0', 'EDO, Inc.', 'Los Angeles, CA', '1 to 50 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 51000.0, 88000),
#  (82, 'Healthcare Data Analyst, Qsight', '$51K-$88K (Glassdoor est.)', '3.3', 'Guidepoint', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Research & Development', 'Business Services', 'Unknown / Non-Applicable', 51000.0, 88000),
#  (83, 'BA/Data Analyst', '$51K-$88K (Glassdoor est.)', '4.1', 'Mitchell Martin', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$100 to $500 million (USD)', 51000.0, 88000),
#  (84, 'Data Analyst Python', '$51K-$88K (Glassdoor est.)', '4.0', 'Lorven Technologies Inc', 'Plainsboro, NJ', '1 to 50 employees', 'Company - Private', 'Accounting', 'Accounting & Legal', 'Less than $1 million (USD)', 51000.0, 88000),
#  (86, 'Data Analyst-BA', '$51K-$88K (Glassdoor est.)', '1.0', 'Sphinix Network Solutions Inc.', 'New York, NY', '1 to 50 employees', 'Company - Private', 'IT Services', 'Information Technology', 'Less than $1 million (USD)', 51000.0, 88000),
#  (87, 'Data Analytics Solutions Analyst', '$51K-$88K (Glassdoor est.)', '3.1', 'Praescient Analytics', 'Alexandria, VA', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$10 to $25 million (USD)', 51000.0, 88000),
#  (88, 'Quantitative Data Analyst', '$51K-$88K (Glassdoor est.)', '4.5', 'Global Atlantic Financial Group', 'New York, NY', '1001 to 5000 employees', 'Company - Private', 'Insurance Carriers', 'Insurance', 'Unknown / Non-Applicable', 51000.0, 88000),
#  (89, 'Data Analyst', '$51K-$88K (Glassdoor est.)', '3.4', 'FINRA', 'Washington, DC', '1001 to 5000 employees', 'Nonprofit Organization', 'Brokerage Services', 'Finance', '$500 million to $1 billion (USD)', 51000.0, 88000),
#  (91, 'Descriptive Analytics Data Analyst, IB', '$51K-$87K (Glassdoor est.)', '3.6', 'Jefferies', 'New York, NY', '1001 to 5000 employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$2 to $5 billion (USD)', 51000.0, 87000),
#  (92, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '4.1', 'RGP', 'Irvine, CA', '1001 to 5000 employees', 'Company - Public', 'Consulting', 'Business Services', '$500 million to $1 billion (USD)', 51000.0, 87000),
#  (93, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '4.4', 'Tachyon Technologies', 'Irving, TX', '201 to 500 employees', 'Company - Private', 'IT Services', 'Information Technology', '$10 to $25 million (USD)', 51000.0, 87000),
#  (94, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '3.8', 'Apex Systems', 'Glen Allen, VA', '1001 to 5000 employees', 'Subsidiary or Business Segment', 'Staffing & Outsourcing', 'Business Services', '$2 to $5 billion (USD)', 51000.0, 87000),
#  (95, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '3.2', 'Hagerty Consulting', 'Evanston, IL', '1 to 50 employees', 'Company - Private', 'Consulting', 'Business Services', '$1 to $5 million (USD)', 51000.0, 87000),
#  (97, 'Business Data Analyst', '$51K-$87K (Glassdoor est.)', '3.8', 'Cortex consultants LLC', 'North Brunswick, NJ', '501 to 1000 employees', 'Company - Private', 'Consulting', 'Business Services', 'Unknown / Non-Applicable', 51000.0, 87000),
#  (98, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '4.7', 'Medly Pharmacy', 'Brooklyn, NY', '201 to 500 employees', 'Unknown', 'Health Care Services & Hospitals', 'Health Care', 'Unknown / Non-Applicable', 51000.0, 87000),
#  (100, 'Supply Chain Data Analyst', '$51K-$87K (Glassdoor est.)', '3.8', 'Peloton Interactive', 'New York, NY', '1001 to 5000 employees', 'Company - Public', 'Health, Beauty, & Fitness', 'Consumer Services', 'Unknown / Non-Applicable', 51000.0, 87000),
#  (101, 'Data Analyst - IBM Tool Set', '$51K-$87K (Glassdoor est.)', '4.6', 'ektello', 'Troy, MI', '201 to 500 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$10 to $25 million (USD)', 51000.0, 87000),
#  (102, 'Analyst-Data Integrity', '$51K-$87K (Glassdoor est.)', '3.0', 'Premier, Inc.', 'Charlotte, NC', '1001 to 5000 employees', 'Company - Public', 'Health Care Services & Hospitals', 'Health Care', '$1 to $2 billion (USD)', 51000.0, 87000),
#  (103, 'Reference Data Operations Analyst - Index Instrument, Associate', '$51K-$87K (Glassdoor est.)', '3.9', 'JPMorgan Chase', 'New York, NY', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 51000.0, 87000),
#  (104, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '3.0', 'Fund for Public Health', 'New York, NY', '201 to 500 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$25 to $50 million (USD)', 51000.0, 87000),
#  (106, 'Data/Systems Analyst', '$51K-$87K (Glassdoor est.)', '5.0', 'Crossfire Consulting Corporation', 'Yorktown Heights, NY', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$5 to $10 million (USD)', 51000.0, 87000),
#  (107, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '4.0', 'Reliable Software Resources', 'Northville, MI', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 51000.0, 87000),
#  (110, 'Data Analyst Intern', '$51K-$87K (Glassdoor est.)', '3.6', 'My Job Tank', 'New York, NY', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', 'Unknown / Non-Applicable', 51000.0, 87000),
#  (111, 'Data Analytics Analyst or Associate, Cowen Sustainable Investments', '$51K-$87K (Glassdoor est.)', '3.7', 'Cowen', 'New York, NY', '501 to 1000 employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$100 to $500 million (USD)', 51000.0, 87000),
#  (112, 'Data Reporting Analyst', '$51K-$87K (Glassdoor est.)', '3.5', 'Robert Half', 'Menlo Park, CA', '10000+ employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$2 to $5 billion (USD)', 51000.0, 87000),
#  (113, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '2.8', 'FJA-US Inc.', 'New York, NY', '51 to 200 employees', 'Subsidiary or Business Segment', 'Computer Hardware & Software', 'Information Technology', '$25 to $50 million (USD)', 51000.0, 87000),
#  (114, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '5.0', 'Averity', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 51000.0, 87000),
#  (115, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '3.8', 'Capgemini', 'Paris, France', '10000+ employees', 'Company - Public', 'Enterprise Software & Network Solutions', 'Information Technology', '$10+ billion (USD)', 51000.0, 87000),
#  (116, 'ERP Data Analyst', '$51K-$87K (Glassdoor est.)', '3.4', 'Wildlife Conservation Society', 'Bronx, NY', '1001 to 5000 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$100 to $500 million (USD)', 51000.0, 87000),
#  (117, 'Data Analyst', '$51K-$87K (Glassdoor est.)', '3.6', 'Asembia', 'Florham Park, NJ', '501 to 1000 employees', 'Company - Private', 'Biotech & Pharmaceuticals', 'Biotech & Pharmaceuticals', '$5 to $10 million (USD)', 51000.0, 87000),
#  (119, 'PBM Data Analyst', '$51K-$87K (Glassdoor est.)', '3.2', '1199SEIU Funds', 'New York, NY', '1001 to 5000 employees', 'Nonprofit Organization', 'Insurance Carriers', 'Insurance', '$100 to $500 million (USD)', 51000.0, 87000),
#  (120, 'Data Analyst (Temporary Assignment)', '$59K-$85K (Glassdoor est.)', '3.8', 'Nutrafol', 'New York, NY', '51 to 200 employees', 'Other Organization', 'Health, Beauty, & Fitness', 'Consumer Services', 'Unknown / Non-Applicable', 59000.0, 85000),
#  (121, 'Data Analyst', '$59K-$85K (Glassdoor est.)', '3.5', 'New York Life Insurance Co', 'New York, NY', '10000+ employees', 'Company - Private', 'Insurance Agencies & Brokerages', 'Insurance', '$10+ billion (USD)', 59000.0, 85000),
#  (122, 'Market Data Analyst', '$59K-$85K (Glassdoor est.)', '3.5', 'EDP World, Inc.', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$1 to $5 million (USD)', 59000.0, 85000),
#  (124, 'Junior Data Analyst', '$59K-$85K (Glassdoor est.)', '5.0', 'Staffigo Technical Services, LLC', 'Woodridge, IL', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 59000.0, 85000),
#  (125, 'Microsoft Dynamics CRM Data Analyst', '$59K-$85K (Glassdoor est.)', '3.7', 'IBM', 'Armonk, NY', '10000+ employees', 'Company - Public', 'IT Services', 'Information Technology', '$10+ billion (USD)', 59000.0, 85000),
#  (126, 'Practice Analyst Data', '$59K-$85K (Glassdoor est.)', '4.0', 'Northwell Health', 'Lake Success, NY', '10000+ employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$10+ billion (USD)', 59000.0, 85000),
#  (127, 'Buyside - Data Scientist/Research Analyst', '$59K-$85K (Glassdoor est.)', '3.3', 'Huxley', 'London, United Kingdom', '201 to 500 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$25 to $50 million (USD)', 59000.0, 85000),
#  (128, 'Data Analyst - Healthcare Provider Networks and Formularies', '$59K-$85K (Glassdoor est.)', '2.9', 'Vericred', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 59000.0, 85000),
#  (129, 'Electronic Trading Data Analyst', '$59K-$85K (Glassdoor est.)', '3.6', 'Scotiabank', 'Toronto, Canada', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 59000.0, 85000),
#  (130, 'Data Analyst, Center for Developing Brain', '$59K-$85K (Glassdoor est.)', '3.2', 'Child Mind Institute', 'New York, NY', '201 to 500 employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$25 to $50 million (USD)', 59000.0, 85000),
#  (131, 'Data Processing & Performance Analyst', '$59K-$85K (Glassdoor est.)', '3.1', 'Balance Innovations', 'Lenexa, KS', '51 to 200 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', '$1 to $5 million (USD)', 59000.0, 85000),
#  (132, 'Business Analyst - Data Analyst', '$59K-$85K (Glassdoor est.)', '3.4', 'Asset Staffing', 'New York, NY', '201 to 500 employees', 'Contract', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 59000.0, 85000),
#  (133, 'Data Analyst with Rochade', '$59K-$85K (Glassdoor est.)', '4.0', 'Reliable Software Resources', 'Northville, MI', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 59000.0, 85000),
#  (134, 'Advertising Data Analyst', '$59K-$85K (Glassdoor est.)', '4.3', 'Hearst Television, Inc', 'Cincinnati, OH', '51 to 200 employees', 'Company - Private', 'TV Broadcast & Cable Networks', 'Media', '$5 to $10 million (USD)', 59000.0, 85000),
#  (135, 'Product Analyst - Data', '$59K-$85K (Glassdoor est.)', '2.7', 'William Hill US', 'London, United Kingdom', '10000+ employees', 'Company - Public', 'Gambling', 'Arts, Entertainment & Recreation', '$2 to $5 billion (USD)', 59000.0, 85000),
#  (136, 'Senior Data Analyst', '$59K-$85K (Glassdoor est.)', '4.1', 'Rockstar Games', 'New York, NY', '1001 to 5000 employees', 'Subsidiary or Business Segment', 'Video Games', 'Media', '$10 to $25 million (USD)', 59000.0, 85000),
#  (138, 'Market Research Data Analyst - Physician Technology', '$59K-$85K (Glassdoor est.)', '3.1', 'Decision Resources Group', 'Burlington, MA', '1001 to 5000 employees', 'Subsidiary or Business Segment', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 59000.0, 85000),
#  (140, 'Look ML Data Analyst', '$59K-$85K (Glassdoor est.)', '2.9', 'NTT DATA, Inc.', 'Singapore, Singapore', '201 to 500 employees', 'Company - Private', 'Accounting', 'Accounting & Legal', 'Unknown / Non-Applicable', 59000.0, 85000),
#  (141, 'Data Collection Analyst', '$59K-$85K (Glassdoor est.)', '3.9', 'Columbia University', 'New York, NY', '10000+ employees', 'College / University', 'Colleges & Universities', 'Education', '$2 to $5 billion (USD)', 59000.0, 85000),
#  (142, 'Data Analyst', '$59K-$85K (Glassdoor est.)', '4.2', 'Precision technologies corp', 'New Brunswick, NJ', '201 to 500 employees', 'Company - Private', 'IT Services', 'Information Technology', '$10 to $25 million (USD)', 59000.0, 85000),
#  (143, 'DATA ENTRY/ BILLING ANALYST', '$59K-$85K (Glassdoor est.)', '3.9', 'Cactus Holdings', 'Mumbai, India', '1001 to 5000 employees', 'Company - Private', 'Research & Development', 'Business Services', 'Unknown / Non-Applicable', 59000.0, 85000),
#  (144, 'Student Persistence Initiative Data Analyst/Scientist', '$59K-$85K (Glassdoor est.)', '4.2', 'Cuny Research Foundation', 'New York, NY', '10000+ employees', 'Nonprofit Organization', 'Colleges & Universities', 'Education', '$100 to $500 million (USD)', 59000.0, 85000),
#  (146, 'Data Governance Analyst', '$59K-$85K (Glassdoor est.)', '5.0', 'Crossfire Consulting Corporation', 'Yorktown Heights, NY', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$5 to $10 million (USD)', 59000.0, 85000),
#  (147, 'Sr. Business Intelligence Engineer / Data Analyst', '$59K-$85K (Glassdoor est.)', '3.9', 'Amazon', 'Seattle, WA', '10000+ employees', 'Company - Public', 'Internet', 'Information Technology', '$10+ billion (USD)', 59000.0, 85000),
#  (149, 'Data Analyst', '$59K-$85K (Glassdoor est.)', '2.9', 'NTT DATA, Inc.', 'Singapore, Singapore', '201 to 500 employees', 'Company - Private', 'Accounting', 'Accounting & Legal', 'Unknown / Non-Applicable', 59000.0, 85000),
#  (150, 'Data Analyst', '$43K-$76K (Glassdoor est.)', '4.0', 'NYU Langone Health', 'New York, NY', '10000+ employees', 'Hospital', 'Health Care Services & Hospitals', 'Health Care', '$5 to $10 billion (USD)', 43000.0, 76000),
#  (151, 'Healthcare Data/Reporting Analyst', '$43K-$76K (Glassdoor est.)', '3.6', 'HOMETEAM', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Health Care Services & Hospitals', 'Health Care', 'Unknown / Non-Applicable', 43000.0, 76000),
#  (152, 'Data Analyst I - Geriatrics and Palliative Care', '$43K-$76K (Glassdoor est.)', '3.4', 'Mount Sinai Health System', 'New York, NY', '10000+ employees', 'Hospital', 'Health Care Services & Hospitals', 'Health Care', '$1 to $2 billion (USD)', 43000.0, 76000),
#  (154, 'Data Analyst/Rochade', '$43K-$76K (Glassdoor est.)', '3.3', 'Halcyon Solutions, Inc.', 'Dublin, OH', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', '$10 to $25 million (USD)', 43000.0, 76000),
#  (156, 'Data Analyst', '$43K-$76K (Glassdoor est.)', '3.8', 'COUNCIL ON ACCREDITATION', 'New York, NY', '51 to 200 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$10 to $25 million (USD)', 43000.0, 76000),
#  (158, 'Data Analyst II, Division of Gastroenterology (Research)', '$43K-$76K (Glassdoor est.)', '3.4', 'Mount Sinai Health System', 'New York, NY', '10000+ employees', 'Hospital', 'Health Care Services & Hospitals', 'Health Care', '$1 to $2 billion (USD)', 43000.0, 76000),
#  (159, 'Data Analyst, Student Success Program', '$43K-$76K (Glassdoor est.)', '3.2', 'Child Mind Institute', 'New York, NY', '201 to 500 employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$25 to $50 million (USD)', 43000.0, 76000),
#  (160, 'Big Data QA Analyst with Jupyter notebook', '$43K-$76K (Glassdoor est.)', '3.2', 'COOLSOFT', 'Louisville, KY', '51 to 200 employees', 'Company - Private', 'Health, Beauty, & Fitness', 'Consumer Services', '$10 to $25 million (USD)', 43000.0, 76000),
#  (161, 'Analyst, Data Centers Industry', '$43K-$76K (Glassdoor est.)', '3.3', '451 Research', 'New York, NY', '201 to 500 employees', 'Company - Private', 'Research & Development', 'Business Services', 'Unknown / Non-Applicable', 43000.0, 76000),
#  (163, 'Financial - Data Analyst', '$43K-$76K (Glassdoor est.)', '3.8', 'Amenity Analytics', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Enterprise Software & Network Solutions', 'Information Technology', 'Unknown / Non-Applicable', 43000.0, 76000),
#  (164, 'Data Analyst with Data Scanning and Profiling', '$43K-$76K (Glassdoor est.)', '3.3', 'Halcyon Solutions, Inc.', 'Dublin, OH', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', '$10 to $25 million (USD)', 43000.0, 76000),
#  (165, 'Business Analyst - Data Governance', '$43K-$76K (Glassdoor est.)', '4.1', 'Rockstar Games', 'New York, NY', '1001 to 5000 employees', 'Subsidiary or Business Segment', 'Video Games', 'Media', '$10 to $25 million (USD)', 43000.0, 76000),
#  (166, 'Senior Data Analyst - Health Economist', '$43K-$76K (Glassdoor est.)', '2.9', 'Vericred', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 43000.0, 76000),
#  (168, 'Research Analyst (Data Science)', '$43K-$76K (Glassdoor est.)', '3.4', 'APCO Worldwide', 'Washington, DC', '501 to 1000 employees', 'Company - Private', 'Consulting', 'Business Services', '$100 to $500 million (USD)', 43000.0, 76000),
#  (169, 'Data Management Analyst', '$43K-$76K (Glassdoor est.)', '2.5', 'Brooklyn Community Services', 'Brooklyn, NY', '201 to 500 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$25 to $50 million (USD)', 43000.0, 76000),
#  (170, 'Business Analyst / Data Analyst', '$43K-$76K (Glassdoor est.)', '4.4', 'Softcom Systems', 'Princeton, NJ', '1 to 50 employees', 'Company - Private', 'IT Services', 'Information Technology', '$1 to $5 million (USD)', 43000.0, 76000),
#  (171, 'Healthcare Data/Reporting Analyst', '$43K-$76K (Glassdoor est.)', '3.9', 'Diverse Lynx', 'Princeton, NJ', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 43000.0, 76000),
#  (173, 'Sr. Data Profiling Analyst', '$43K-$76K (Glassdoor est.)', '3.6', 'UBS', 'Zurich, Switzerland', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 43000.0, 76000),
#  (175, 'Data Analyst', '$43K-$76K (Glassdoor est.)', '3.6', 'Workforce Logiq', 'Orlando, FL', '501 to 1000 employees', 'Company - Private', 'Consulting', 'Business Services', '$50 to $100 million (USD)', 43000.0, 76000),
#  (176, 'Data Analyst', '$43K-$76K (Glassdoor est.)', '3.3', 'Cross River Bank', 'Fort Lee, NJ', '201 to 500 employees', 'Company - Private', 'Banks & Credit Unions', 'Finance', '$50 to $100 million (USD)', 43000.0, 76000),
#  (177, 'Sr. Data Analyst, Revenue Analytics, Peacock', '$43K-$76K (Glassdoor est.)', '3.8', 'NBCUniversal', 'New York, NY', '10000+ employees', 'Company - Public', 'TV Broadcast & Cable Networks', 'Media', '$10+ billion (USD)', 43000.0, 76000),
#  (178, 'Senior Data Analyst', '$43K-$76K (Glassdoor est.)', '3.7', 'Narrativ', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 43000.0, 76000),
#  (180, 'Senior Data Analyst - Data Cataloging / Data Profiling', '$43K-$76K (Glassdoor est.)', '3.6', 'Perficient', 'Saint Louis, MO', '1001 to 5000 employees', 'Company - Public', 'IT Services', 'Information Technology', '$500 million to $1 billion (USD)', 43000.0, 76000),
#  (181, 'Data/Report Analyst', '$60K-$110K (Glassdoor est.)', '4.0', 'Lorven Technologies Inc', 'Plainsboro, NJ', '1 to 50 employees', 'Company - Private', 'Accounting', 'Accounting & Legal', 'Less than $1 million (USD)', 60000.0, 110000),
#  (182, 'Senior Data Analyst', '$60K-$110K (Glassdoor est.)', '4.1', 'Bounce Exchange', 'New York, NY', '201 to 500 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', 'Unknown / Non-Applicable', 60000.0, 110000),
#  (183, 'Human Capital Data Analyst', '$60K-$110K (Glassdoor est.)', '4.5', 'Green Key Resources', 'New York, NY', '201 to 500 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 60000.0, 110000),
#  (184, 'GIS Data analyst', '$60K-$110K (Glassdoor est.)', '3.7', '22nd Century Technologies', 'Somerset, NJ', '1001 to 5000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$25 to $50 million (USD)', 60000.0, 110000),
#  (185, 'Junior Data Analytics Solutions Analyst', '$60K-$110K (Glassdoor est.)', '3.1', 'Praescient Analytics', 'Alexandria, VA', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$10 to $25 million (USD)', 60000.0, 110000),
#  (187, 'Data Analyst w/Capital Markets', '$60K-$110K (Glassdoor est.)', '3.7', 'Software Guidance & Assistance', 'Tarrytown, NY', '51 to 200 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$50 to $100 million (USD)', 60000.0, 110000),
#  (188, 'VP, Research Project Analyst/Data Management', '$60K-$110K (Glassdoor est.)', '3.7', 'Citi', 'New York, NY', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 60000.0, 110000),
#  (189, 'Food Data Analyst', '$60K-$110K (Glassdoor est.)', '3.2', 'Metropolitan Council on Jewish Poverty', 'New York, NY', '201 to 500 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$25 to $50 million (USD)', 60000.0, 110000),
#  (190, 'Data Management Analyst', '$60K-$110K (Glassdoor est.)', '3.6', 'TSR Consulting', 'Hauppauge, NY', '201 to 500 employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$50 to $100 million (USD)', 60000.0, 110000),
#  (191, 'Data Governance Analyst', '$60K-$110K (Glassdoor est.)', '3.6', 'UBS', 'Zurich, Switzerland', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 60000.0, 110000),
#  (192, 'Data Analyst, Enterprise Analytics', '$60K-$110K (Glassdoor est.)', '3.7', 'Take-Two Interactive Software, Inc.', 'New York, NY', '1001 to 5000 employees', 'Company - Public', 'Video Games', 'Media', '$1 to $2 billion (USD)', 60000.0, 110000),
#  (193, 'Data Analytics Solutions Analyst - Mid with Security Clearance', '$60K-$110K (Glassdoor est.)', '3.1', 'Praescient Analytics', 'Alexandria, VA', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$10 to $25 million (USD)', 60000.0, 110000),
#  (195, 'Investment Management Summer Analyst Program - Office of COO: Data & Analytics', '$60K-$110K (Glassdoor est.)', '3.8', 'Morgan Stanley', 'New York, NY', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 60000.0, 110000),
#  (196, 'Data Collection Analyst', '$60K-$110K (Glassdoor est.)', '4.1', 'ICAP at Columbia University', 'New York, NY', '501 to 1000 employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', 'Unknown / Non-Applicable', 60000.0, 110000),
#  (197, 'Data Collection Analyst', '$60K-$110K (Glassdoor est.)', '3.8', 'Columbia University Medical Center', 'New York, NY', '5001 to 10000 employees', 'Hospital', 'Health Care Services & Hospitals', 'Health Care', '$500 million to $1 billion (USD)', 60000.0, 110000),
#  (198, 'Sr Business /Data Analyst- Reference data', '$60K-$110K (Glassdoor est.)', '3.7', 'Xoriant Corporation', 'Sunnyvale, CA', '1001 to 5000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 60000.0, 110000),
#  (200, 'SENIOR DATA ANALYST', '$60K-$110K (Glassdoor est.)', '3.7', 'Montefiore Medical', 'Bronx, NY', '10000+ employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$2 to $5 billion (USD)', 60000.0, 110000),
#  (201, 'Senior Data Analyst / Scientist', '$60K-$110K (Glassdoor est.)', '3.3', 'Cedent Consulting', 'Frisco, TX', '1 to 50 employees', 'Company - Private', 'Consulting', 'Business Services', 'Less than $1 million (USD)', 60000.0, 110000),
#  (202, 'Senior Data Analyst - Regulatory Reporting', '$60K-$110K (Glassdoor est.)', '3.4', 'ACS', 'Moore, OK', '1 to 50 employees', 'Company - Private', 'General Repair & Maintenance', 'Construction, Repair & Maintenance', '$1 to $5 million (USD)', 60000.0, 110000),
#  (203, 'Data Reporting Analyst', '$60K-$110K (Glassdoor est.)', '3.2', 'NADAP', 'New York, NY', '201 to 500 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', 'Unknown / Non-Applicable', 60000.0, 110000),
#  (206, 'Senior Data Analyst (6-12 Month Contract-Remote)', '$60K-$110K (Glassdoor est.)', '5.0', 'VISTRADA', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', '$1 to $5 million (USD)', 60000.0, 110000),
#  (207, 'Principal Data Analyst, LATAM – Disney Streaming Services', '$60K-$110K (Glassdoor est.)', '3.6', 'Disney Streaming Services', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Internet', 'Information Technology', 'Unknown / Non-Applicable', 60000.0, 110000),
#  (208, 'Data Analyst- Win 10 Migration- NYC', '$60K-$110K (Glassdoor est.)', '3.0', 'Royal Communications Consultants Inc', 'New York, NY', '1 to 50 employees', 'Company - Private', 'IT Services', 'Information Technology', '$1 to $5 million (USD)', 60000.0, 110000),
#  (209, 'Data Analyst (35 hours/week)', '$60K-$110K (Glassdoor est.)', '3.5', 'CASES', 'Brooklyn, NY', '201 to 500 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$10 to $25 million (USD)', 60000.0, 110000),
#  (210, 'Tech Business/Data Analyst', '$60K-$110K (Glassdoor est.)', '1.0', 'Sphinix Network Solutions Inc.', 'New York, NY', '1 to 50 employees', 'Company - Private', 'IT Services', 'Information Technology', 'Less than $1 million (USD)', 60000.0, 110000),
#  (211, 'Data Analyst', '$41K-$78K (Glassdoor est.)', '5.0', 'Staffigo Technical Services, LLC', 'Woodridge, IL', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 41000.0, 78000),
#  (212, 'Senior Data Analyst, Financial Services', '$41K-$78K (Glassdoor est.)', '5.0', 'Earnest Research', 'New York, NY', '51 to 200 employees', 'Company - Private', 'Research & Development', 'Business Services', 'Unknown / Non-Applicable', 41000.0, 78000),
#  (213, 'Enterprise Data, Financial Data Analyst - Content Design Specialist Contractor', '$41K-$78K (Glassdoor est.)', '3.8', 'Bloomberg', 'New York, NY', '10000+ employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', 'Unknown / Non-Applicable', 41000.0, 78000),
#  (214, 'Data Analyst', '$41K-$78K (Glassdoor est.)', '4.1', 'APN Software Services Inc.', 'Newark, CA', '51 to 200 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', '$25 to $50 million (USD)', 41000.0, 78000),
#  (215, 'Data Analyst', '$41K-$78K (Glassdoor est.)', '3.3', 'Acacia Network', 'Bronx, NY', '1001 to 5000 employees', 'Nonprofit Organization', 'Social Assistance', 'Non-Profit', '$100 to $500 million (USD)', 41000.0, 78000),
#  (217, 'Data Remediation Analyst-EK020719A/JL', '$41K-$78K (Glassdoor est.)', '3.5', 'EDP World, Inc.', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$1 to $5 million (USD)', 41000.0, 78000),
#  (218, 'Business Analyst - Chief Data Office', '$41K-$78K (Glassdoor est.)', '3.7', 'Citi', 'New York, NY', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 41000.0, 78000),
#  (219, 'Senior Analyst, Data Instrumentation & Quality (Disney+)', '$41K-$78K (Glassdoor est.)', '4.0', 'Walt Disney Co.', 'Burbank, CA', '10000+ employees', 'Company - Public', 'Motion Picture Production & Distribution', 'Media', '$10+ billion (USD)', 41000.0, 78000),
#  (220, 'Sr. Data Analyst', '$41K-$78K (Glassdoor est.)', '3.4', 'NTT DATA', 'Tokyo, Japan', '10000+ employees', 'Company - Public', 'IT Services', 'Information Technology', '$10+ billion (USD)', 41000.0, 78000),
#  (221, 'Big Data Programmer Analyst', '$41K-$78K (Glassdoor est.)', '3.6', 'TSR, Inc.', 'Hauppauge, NY', '201 to 500 employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$50 to $100 million (USD)', 41000.0, 78000),
#  (223, 'Data Analyst', '$41K-$78K (Glassdoor est.)', '3.5', 'Fidelis Group', 'Little Ferry, NJ', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$10 to $25 million (USD)', 41000.0, 78000),
#  (224, 'Data Governance Analyst', '$41K-$78K (Glassdoor est.)', '3.4', 'Eclaro', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$25 to $50 million (USD)', 41000.0, 78000),
#  (226, 'Financial Data Analyst - Accounting - D3529', '$41K-$78K (Glassdoor est.)', '4.2', 'Source of Future Technology Inc', 'New York, NY', '1 to 50 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', '$5 to $10 million (USD)', 41000.0, 78000),
#  (228, 'Data Processing & Performance Analyst New York, NY', '$41K-$78K (Glassdoor est.)', '2.7', "Brink's", 'Richmond, VA', '10000+ employees', 'Company - Public', 'Security Services', 'Business Services', '$2 to $5 billion (USD)', 41000.0, 78000),
#  (229, 'Data Analyst', '$41K-$78K (Glassdoor est.)', '3.1', 'Seven Seven Softwares', 'Rockaway, NJ', '201 to 500 employees', 'Company - Public', 'IT Services', 'Information Technology', '$10 to $25 million (USD)', 41000.0, 78000),
#  (230, 'Senior Data Analyst', '$41K-$78K (Glassdoor est.)', '4.5', 'Mobilityware', 'Irvine, CA', '51 to 200 employees', 'Company - Private', 'Video Games', 'Media', 'Unknown / Non-Applicable', 41000.0, 78000),
#  (231, 'Data Analyst-Junior Profiles also works-Only NY/NJ Candidates Please on w2 Only', '$41K-$78K (Glassdoor est.)', '4.8', 'TechProjects', 'North Brunswick, NJ', '1 to 50 employees', 'Company - Private', 'IT Services', 'Information Technology', 'Unknown / Non-Applicable', 41000.0, 78000),
#  (232, 'Business Analyst-Market Data', '$41K-$78K (Glassdoor est.)', '4.1', 'Mitchell Martin', 'New York, NY', '501 to 1000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$100 to $500 million (USD)', 41000.0, 78000),
#  (233, 'Content Analyst/Data BA-Bus/Tech Strategy - Investment Bank', '$41K-$78K (Glassdoor est.)', '3.0', 'RMS Computer Corporation', 'New York, NY', '201 to 500 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', '$25 to $50 million (USD)', 41000.0, 78000),
#  (234, 'Data Analyst', '$41K-$78K (Glassdoor est.)', '2.7', 'ProHEALTH Care', 'Lake Success, NY', '1001 to 5000 employees', 'Subsidiary or Business Segment', 'Health Care Services & Hospitals', 'Health Care', 'Unknown / Non-Applicable', 41000.0, 78000),
#  (235, 'Senior Analyst, AB Testing and Data Operations', '$41K-$78K (Glassdoor est.)', '3.5', '2U', 'Lanham, MD', '1001 to 5000 employees', 'Company - Public', 'Enterprise Software & Network Solutions', 'Information Technology', '$100 to $500 million (USD)', 41000.0, 78000),
#  (237, 'Data Analyst I - Geriatrics and Palliative Care', '$41K-$78K (Glassdoor est.)', '3.1', 'Mount Sinai Medical Center', 'Miami Beach, FL', '1001 to 5000 employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$500 million to $1 billion (USD)', 41000.0, 78000),
#  (238, 'Data Analyst', '$41K-$78K (Glassdoor est.)', '5.0', 'Professional Resource Group', 'Spring, TX', '1 to 50 employees', 'Company - Private', 'Advertising & Marketing', 'Business Services', 'Less than $1 million (USD)', 41000.0, 78000),
#  (239, 'Senior Business and Data Analyst', '$41K-$78K (Glassdoor est.)', '3.9', 'JPMorgan Chase', 'New York, NY', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 41000.0, 78000),
#  (240, 'Data Analyst II', '$45K-$88K (Glassdoor est.)', '3.8', 'Capgemini', 'Paris, France', '10000+ employees', 'Company - Public', 'Enterprise Software & Network Solutions', 'Information Technology', '$10+ billion (USD)', 45000.0, 88000),
#  (391, 'TX Healthcare Data/Reporting Analyst', '$98K-$114K (Glassdoor est.)', '3.4', 'RN Staff', 'Westfield, IN', 'Unknown', 'Unknown', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 98000.0, 114000),
# ...
#  (1164, 'Data Analyst and Report Writer', '$64K-$113K (Glassdoor est.)', '3.5', 'The Judge Group', 'Wayne, PA', '1001 to 5000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$100 to $500 million (USD)', 64000.0, 113000),
#  (1165, 'Payment Integrity Data Analyst', '$64K-$113K (Glassdoor est.)', '3.7', 'amerihealth', 'Philadelphia, PA', '5001 to 10000 employees', 'Subsidiary or Business Segment', 'Insurance Carriers', 'Insurance', '$25 to $50 million (USD)', 64000.0, 113000),
#  (1166, 'Lead Data Analyst', '$64K-$113K (Glassdoor est.)', '3.9', 'GSK', 'Brentford, United Kingdom', '10000+ employees', 'Company - Public', 'Biotech & Pharmaceuticals', 'Biotech & Pharmaceuticals', '$10+ billion (USD)', 64000.0, 113000),
#  (1167, 'Data Analyst-(analytics)', '$64K-$113K (Glassdoor est.)', '3.6', 'A2C Consulting', 'Philadelphia, PA', '1 to 50 employees', 'Company - Private', 'Consulting', 'Business Services', 'Unknown / Non-Applicable', 64000.0, 113000),
#  (1170, 'Virology Data Analysts', '$64K-$113K (Glassdoor est.)', '3.4', 'Eurofins', 'Luxembourg, Luxembourg', '10000+ employees', 'Company - Private', 'Biotech & Pharmaceuticals', 'Biotech & Pharmaceuticals', '$2 to $5 billion (USD)', 64000.0, 113000),
#  (1171, 'Biochemist Data Analyst', '$64K-$113K (Glassdoor est.)', '3.4', 'Eurofins', 'Luxembourg, Luxembourg', '10000+ employees', 'Company - Private', 'Biotech & Pharmaceuticals', 'Biotech & Pharmaceuticals', '$2 to $5 billion (USD)', 64000.0, 113000),
#  (1172, 'Data Governance Analyst', '$64K-$113K (Glassdoor est.)', '4.2', 'Freedom Mortgage', 'Mount Laurel, NJ', '1001 to 5000 employees', 'Company - Private', 'Investment Banking & Asset Management', 'Finance', '$1 to $2 billion (USD)', 64000.0, 113000),
#  (1173, 'Senior Healthcare Data Analyst', '$64K-$113K (Glassdoor est.)', '5.0', 'Cambridge Advisory Group', 'King of Prussia, PA', '1 to 50 employees', 'Company - Private', 'Consulting', 'Business Services', '$1 to $5 million (USD)', 64000.0, 113000),
#  (1175, 'SR BUSINESS DATA ANALYST PRN', '$64K-$113K (Glassdoor est.)', '3.3', 'Cooper University Health Care', 'Camden, NJ', '5001 to 10000 employees', 'Hospital', 'Health Care Services & Hospitals', 'Health Care', 'Unknown / Non-Applicable', 64000.0, 113000),
#  (1176, 'AWS Analys/ Data analyst', '$64K-$113K (Glassdoor est.)', '3.9', 'Diverse Lynx', 'Princeton, NJ', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 64000.0, 113000),
#  (1177, 'Payment Integrity Data Analyst Job posting in #Philadelphia #ITjobs', '$64K-$113K (Glassdoor est.)', '3.7', 'amerihealth', 'Philadelphia, PA', '5001 to 10000 employees', 'Subsidiary or Business Segment', 'Insurance Carriers', 'Insurance', '$25 to $50 million (USD)', 64000.0, 113000),
#  (1179, 'Data Analyst Supporting the FBI #20-188', '$64K-$113K (Glassdoor est.)', '2.8', 'Forfeiture Support Associates', 'Ashburn, VA', '1001 to 5000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$50 to $100 million (USD)', 64000.0, 113000),
#  (1180, 'Data Engineer/Reporting Analyst', '$64K-$113K (Glassdoor est.)', '1.6', 'Management Decisions, Inc.', 'Milwaukee, WI', '1 to 50 employees', 'Company - Public', 'Advertising & Marketing', 'Business Services', '$1 to $5 million (USD)', 64000.0, 113000),
#  (1181, 'Sr. Data Analyst - Project Manager', '$64K-$113K (Glassdoor est.)', '2.7', 'TechUSA', 'Millersville, MD', '1001 to 5000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$100 to $500 million (USD)', 64000.0, 113000),
#  (1182, 'Data Analyst SAS Programmer', '$50K-$93K (Glassdoor est.)', '4.6', 'SRG Woolf', 'Raleigh, NC', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$10 to $25 million (USD)', 50000.0, 93000),
#  (1183, 'Sr. Data Analyst', '$50K-$93K (Glassdoor est.)', '3.8', 'Login Consulting Services, Inc', 'El Segundo, CA', '51 to 200 employees', 'Company - Private', 'Consulting', 'Business Services', '$5 to $10 million (USD)', 50000.0, 93000),
#  (1184, 'Systems Analyst, Quality Data System', '$50K-$93K (Glassdoor est.)', '3.3', 'Adaptimmune Ltd', 'Abingdon, United Kingdom', '201 to 500 employees', 'Company - Public', 'Biotech & Pharmaceuticals', 'Biotech & Pharmaceuticals', 'Unknown / Non-Applicable', 50000.0, 93000),
#  (1185, 'Data Visualization Project Manager/ Business Analyst (PM / BA)', '$50K-$93K (Glassdoor est.)', '4.8', 'Trillium Solutions Group', 'Highland Park, IL', '1 to 50 employees', 'Private Practice / Firm', 'IT Services', 'Information Technology', '$1 to $5 million (USD)', 50000.0, 93000),
#  (1187, 'Business Analyst/Data Analyst', '$50K-$93K (Glassdoor est.)', '3.5', 'The Judge Group', 'Wayne, PA', '1001 to 5000 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$100 to $500 million (USD)', 50000.0, 93000),
#  (1189, 'Data Analyst Junior', '$50K-$93K (Glassdoor est.)', '5.0', 'Staffigo Technical Services, LLC', 'Woodridge, IL', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 50000.0, 93000),
#  (1190, 'Business Intelligence and Data Sciences Analyst', '$50K-$93K (Glassdoor est.)', '3.6', 'TE Connectivity', 'Schaffhausen, Switzerland', '10000+ employees', 'Company - Public', 'Electrical & Electronic Manufacturing', 'Manufacturing', '$10+ billion (USD)', 50000.0, 93000),
#  (1191, 'Sr Business Analyst (Data Quality)', '$50K-$93K (Glassdoor est.)', '4.2', 'Freedom Mortgage', 'Mount Laurel, NJ', '1001 to 5000 employees', 'Company - Private', 'Investment Banking & Asset Management', 'Finance', '$1 to $2 billion (USD)', 50000.0, 93000),
#  (1192, 'Healthcare Data Analytics Analyst Senior', '$50K-$93K (Glassdoor est.)', '3.1', 'AmeriHealth Caritas', 'Philadelphia, PA', '5001 to 10000 employees', 'Company - Private', 'Insurance Carriers', 'Insurance', '$5 to $10 billion (USD)', 50000.0, 93000),
#  (1193, 'Mid Level Data Analyst / BI Engineer - Looker, Python, Client Facing', '$50K-$93K (Glassdoor est.)', '1.6', 'Management Decisions, Inc.', 'Milwaukee, WI', '1 to 50 employees', 'Company - Public', 'Advertising & Marketing', 'Business Services', '$1 to $5 million (USD)', 50000.0, 93000),
#  (1194, 'Technical Business Analyst (Data Warehouse)', '$50K-$93K (Glassdoor est.)', '4.5', 'Piper Companies', 'Mc Lean, VA', '201 to 500 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 50000.0, 93000),
#  (1195, 'Data Link Analyst', '$50K-$93K (Glassdoor est.)', '3.3', 'Future Technologies Inc.', 'Plainfield, NJ', '1001 to 5000 employees', 'Company - Private', 'Accounting', 'Accounting & Legal', '$5 to $10 million (USD)', 50000.0, 93000),
#  (1196, 'Lead Analyst, Data Transfer, Integration & Quality, Wilmington, DE', '$50K-$93K (Glassdoor est.)', '3.2', 'BNY Mellon', 'New York, NY', '10000+ employees', 'Company - Public', 'Investment Banking & Asset Management', 'Finance', '$10+ billion (USD)', 50000.0, 93000),
#  (1197, 'Technical Business Analyst (Data Warehouse)', '$50K-$93K (Glassdoor est.)', '3.9', 'Zachary Piper Solutions, LLC', 'Mc Lean, VA', '51 to 200 employees', 'Company - Private', 'Enterprise Software & Network Solutions', 'Information Technology', '$10 to $25 million (USD)', 50000.0, 93000),
#  (1198, 'Certified Tumor Registrar/Data Analyst [CTR and experience required]', '$50K-$93K (Glassdoor est.)', '4.0', 'Fox Chase Cancer Center', 'Philadelphia, PA', '1001 to 5000 employees', 'Nonprofit Organization', 'Health Care Services & Hospitals', 'Health Care', '$100 to $500 million (USD)', 50000.0, 93000),
#  (1199, 'Data Center Migration PMO Analyst/PMO Lead', '$50K-$93K (Glassdoor est.)', '4.1', 'Kforce', 'Tampa, FL', '10000+ employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$1 to $2 billion (USD)', 50000.0, 93000),
#  (1201, 'Data Analyst / Tableau Developer', '$37K-$68K (Glassdoor est.)', '3.9', 'Technocrafts, Inc.', 'Chantilly, VA', '1 to 50 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', '$1 to $5 million (USD)', 37000.0, 68000),
#  (1202, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '3.4', 'Ionidea', 'Fairfax, VA', '1001 to 5000 employees', 'Company - Private', 'IT Services', 'Information Technology', 'Unknown / Non-Applicable', 37000.0, 68000),
#  (1203, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '4.0', 'CYNET SYSTEMS', 'Ashburn, VA', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 37000.0, 68000),
#  (1204, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '3.1', 'Integrated Resources', 'Edison, NJ', '201 to 500 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$25 to $50 million (USD)', 37000.0, 68000),
#  (1205, 'Data Analyst I', '$37K-$68K (Glassdoor est.)', '3.0', 'Deacon Recruiting', 'San Antonio, TX', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$1 to $5 million (USD)', 37000.0, 68000),
#  (1206, 'Data Reporting Analyst', '$37K-$68K (Glassdoor est.)', '3.9', 'Indotronix International Corporation', 'Rochester, NY', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 37000.0, 68000),
#  (1207, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '3.9', 'Diverse Lynx', 'Princeton, NJ', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 37000.0, 68000),
#  (1208, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '3.7', 'Huntington Ingalls Industries', 'Newport News, VA', '10000+ employees', 'Company - Public', 'Aerospace & Defense', 'Aerospace & Defense', '$5 to $10 billion (USD)', 37000.0, 68000),
#  (1209, 'Marketing & Data Analyst', '$37K-$68K (Glassdoor est.)', '4.1', 'Principle Auto', 'San Antonio, TX', '501 to 1000 employees', 'Company - Private', 'Vehicle Dealers', 'Retail', 'Unknown / Non-Applicable', 37000.0, 68000),
#  (1210, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '3.4', 'C2 GPS- Alamo Workforce', 'Austin, TX', '501 to 1000 employees', 'Company - Private', 'Consulting', 'Business Services', 'Unknown / Non-Applicable', 37000.0, 68000),
#  (1211, 'Data Reporting Analyst', '$37K-$68K (Glassdoor est.)', '3.4', 'Vantage Bank Texas', 'San Antonio, TX', '201 to 500 employees', 'Company - Private', 'Banks & Credit Unions', 'Finance', '$1 to $2 billion (USD)', 37000.0, 68000),
#  (1212, 'Data & Reporting Analyst, Distribution Planning & Operations', '$37K-$68K (Glassdoor est.)', '4.3', 'H E B', 'San Antonio, TX', '10000+ employees', 'Company - Private', 'Grocery Stores & Supermarkets', 'Retail', '$10+ billion (USD)', 37000.0, 68000),
#  (1214, 'Epidemiologist - Data Analyst', '$37K-$68K (Glassdoor est.)', '4.0', 'CICONIX, LLC', 'Annapolis, MD', '1 to 50 employees', 'Company - Private', 'Federal Agencies', 'Government', 'Unknown / Non-Applicable', 37000.0, 68000),
#  (1216, 'Epidemiology Data Analyst', '$37K-$68K (Glassdoor est.)', '2.8', 'NJVC', 'Chantilly, VA', '1001 to 5000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 37000.0, 68000),
#  (1217, 'Data Business Solutions Analyst', '$37K-$68K (Glassdoor est.)', '3.7', 'Randstad', 'Atlanta, GA', '1001 to 5000 employees', 'Subsidiary or Business Segment', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 37000.0, 68000),
#  (1218, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '5.0', 'Staffigo Technical Services, LLC', 'Woodridge, IL', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 37000.0, 68000),
#  (1219, 'Risk Data Analyst', '$37K-$68K (Glassdoor est.)', '3.0', 'Deacon Recruiting', 'San Antonio, TX', '1 to 50 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$1 to $5 million (USD)', 37000.0, 68000),
#  (1220, 'Contract Data Analyst', '$37K-$68K (Glassdoor est.)', '4.0', 'Amyx, Inc.', 'Reston, VA', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$50 to $100 million (USD)', 37000.0, 68000),
#  (1221, 'Senior Data Analyst', '$37K-$68K (Glassdoor est.)', '4.5', 'Scaleworks', 'San Antonio, TX', '1 to 50 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', 'Unknown / Non-Applicable', 37000.0, 68000),
#  (1222, 'Senior Data Analyst', '$37K-$68K (Glassdoor est.)', '3.5', 'HCL Technologies Ltd.', 'Noida, India', '10000+ employees', 'Company - Public', 'Computer Hardware & Software', 'Information Technology', '$5 to $10 billion (USD)', 37000.0, 68000),
#  (1223, 'Data Analyst', '$37K-$68K (Glassdoor est.)', '3.3', 'CDO Technologies Inc', 'Dayton, OH', '201 to 500 employees', 'Company - Private', 'Computer Hardware & Software', 'Information Technology', '$50 to $100 million (USD)', 37000.0, 68000),
#  (1225, 'Senior Data Analyst', '$37K-$68K (Glassdoor est.)', '4.1', 'Kforce', 'Tampa, FL', '10000+ employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$1 to $2 billion (USD)', 37000.0, 68000),
#  (1226, 'Senior Data Science Analyst', '$37K-$68K (Glassdoor est.)', '2.9', 'PETCO', 'San Diego, CA', '10000+ employees', 'Company - Private', 'Pet & Pet Supplies Stores', 'Retail', '$2 to $5 billion (USD)', 37000.0, 68000),
#  (1227, 'Data Analyst ( SAS,SQL)', '$37K-$68K (Glassdoor est.)', '3.7', 'eTeam Inc.', 'South Plainfield, NJ', '51 to 200 employees', 'Company - Private', 'Staffing & Outsourcing', 'Business Services', '$50 to $100 million (USD)', 37000.0, 68000),
#  (1228, 'Data Analyst - Top Secret w/ SCI Eligibility', '$37K-$68K (Glassdoor est.)', '4.0', 'LMI', 'Tysons, VA', '1001 to 5000 employees', 'Nonprofit Organization', 'Consulting', 'Business Services', '$100 to $500 million (USD)', 37000.0, 68000),
#  (1229, 'Epidemiology/Data Analyst', '$37K-$68K (Glassdoor est.)', '4.0', 'CAMRIS International', 'Bethesda, MD', '201 to 500 employees', 'Company - Private', 'Federal Agencies', 'Government', '$50 to $100 million (USD)', 37000.0, 68000),
#  (1230, 'Epidemiology Data Analyst', '$37K-$68K (Glassdoor est.)', '3.5', 'General Dynamics Information Technology', 'Fairfax, VA', '10000+ employees', 'Subsidiary or Business Segment', 'IT Services', 'Information Technology', '$10+ billion (USD)', 37000.0, 68000),
#  (1231, 'Senior Data Analyst', '$73K-$89K (Glassdoor est.)', '3.3', 'Convene Technologies', 'Tampa, FL', '51 to 200 employees', 'Company - Private', 'IT Services', 'Information Technology', 'Unknown / Non-Applicable', 73000.0, 89000),
#  (1233, 'Data Security Analyst', '$73K-$89K (Glassdoor est.)', '2.6', 'nana', 'Kotzebue, AK', '1001 to 5000 employees', 'Unknown', 'Social Assistance', 'Non-Profit', '$2 to $5 billion (USD)', 73000.0, 89000),
#  (1234, 'Data Security Analyst', '$73K-$89K (Glassdoor est.)', '3.3', 'Akima Management Services', 'Herndon, VA', '5001 to 10000 employees', 'Company - Private', 'Aerospace & Defense', 'Aerospace & Defense', '$1 to $2 billion (USD)', 73000.0, 89000),
#  (1235, 'Data Analyst/Engineers', '$73K-$89K (Glassdoor est.)', '3.9', 'Diverse Lynx', 'Princeton, NJ', '501 to 1000 employees', 'Company - Private', 'IT Services', 'Information Technology', '$100 to $500 million (USD)', 73000.0, 89000),
#  (1237, 'Epidemiology Data Analyst', '$73K-$89K (Glassdoor est.)', '3.8', 'Chenega Healthcare Services', 'San Antonio, TX', '501 to 1000 employees', 'Subsidiary or Business Segment', 'Staffing & Outsourcing', 'Business Services', 'Unknown / Non-Applicable', 73000.0, 89000),
#  (1238, 'IT Data Science Analyst', '$73K-$89K (Glassdoor est.)', '4.1', 'Kforce', 'Tampa, FL', '10000+ employees', 'Company - Public', 'Staffing & Outsourcing', 'Business Services', '$1 to $2 billion (USD)', 73000.0, 89000),
#  ...]

# %%
data_list=[]
for row in rows:
    data_list.append(list(row))

# %%
class Encoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, decimal.Decimal): return float(obj)

json_file=json.dumps(data_list , cls = Encoder)

# %%
# Out:
# str

# %%
table=Base.classes.data_analyst

# %%
session=Session(engine)

# %%
min_by_location=session.query(table.Location,func.sum(table.min)).group_by(table.Location).all()

# %%
min_by_location
# Out:
# [('Burbank, CA', 765000.0),
#  ('Lackland AFB, TX', 110000.0),
#  ('Emeryville, CA', 82000.0),
#  ('Foster City, CA', 590000.0),
#  ('Torrance, CA', 42000.0),
#  ('Redmond, WA', 505000.0),
#  ('Alameda, CA', 47000.0),
#  ('Southlake, TX', 44000.0),
#  ('Riverton, UT', 26000.0),
#  ('Paoli, PA', 37000.0),
#  ('Anaheim, CA', 94000.0),
#  ('Fort Lee, NJ', 43000.0),
#  ('Jacksonville, FL', 600000.0),
#  ('Grapevine, TX', 112000.0),
#  ('Hanford, CA', 47000.0),
#  ('Doylestown, PA', 37000.0),
#  ('Richardson, TX', 406000.0),
#  ('Conshohocken, PA', 37000.0),
#  ('Bensalem, PA', 38000.0),
#  ('Denver, CO', 2496000.0),
#  ('Mountain View, CA', 800000.0),
#  ('West Conshohocken, PA', 38000.0),
#  ('Draper, UT', 52000.0),
#  ('Queens Village, NY', 59000.0),
#  ('Beech Grove, IN', 34000.0),
#  ('Campbell, CA', 63000.0),
#  ('Yorktown, VA', 43000.0),
#  ('Dallas, TX', 1788000.0),
#  ('Harrison, NY', 48000.0),
#  ('Lake Success, NY', 470000.0),
#  ('Santa Clara, CA', 1486000.0),
#  ('King of Prussia, PA', 231000.0),
#  ('Chesapeake, VA', 141000.0),
#  ('Arcadia, CA', 226000.0),
#  ('Santa Monica, CA', 515000.0),
#  ('Bellevue, WA', 35000.0),
#  ('Philadelphia, PA', 2297000.0),
#  ('Salt Lake City, UT', 379000.0),
#  ('Berkeley Heights, NJ', 27000.0),
#  ('Newark, CA', 220000.0),
#  ('Long Island City, NY', 51000.0),
#  ('Pleasanton, CA', 223000.0),
#  ('Allen, TX', 116000.0),
#  ('Wayne, PA', 241000.0),
#  ('Weehawken, NJ', 149000.0),
#  ('Indianapolis, IN', 544000.0),
#  ('Berkeley, CA', 164000.0),
#  ('Burlingame, CA', 304000.0),
#  ('El Cajon, CA', 60000.0),
#  ('Ridley Park, PA', 37000.0),
#  ('Milpitas, CA', 225000.0),
#  ('Culver City, CA', 181000.0),
#  ('San Antonio, TX', 1911000.0),
#  ('Scottsdale, AZ', 523000.0),
#  ('Oakland, CA', 501000.0),
#  ('Spring, TX', 74000.0),
#  ('Gainesville, FL', 210000.0),
#  ('Montvale, NJ', 48000.0),
#  ('Palo Alto, CA', 840000.0),
#  ('Boulder, CO', 163000.0),
#  ('Walnut Creek, CA', 94000.0),
#  ('Coppell, TX', 44000.0),
#  ('Blue Bell, PA', 41000.0),
#  ('Houston, TX', 2928000.0),
#  ('Boothwyn, PA', 64000.0),
#  ('Round Rock, TX', 113000.0),
#  ('Englewood, CO', 269000.0),
#  ('Northfield, IL', 97000.0),
#  ('Littleton, CO', 57000.0),
#  ('Visalia, CA', 47000.0),
#  ('Cedar Park, TX', 35000.0),
#  ('Radnor, PA', 38000.0),
#  ('Horsham, PA', 299000.0),
#  ('Manhasset, NY', 143000.0),
#  ('Tarrant, TX', 44000.0),
#  ('Glenview, IL', 97000.0),
#  ('Cupertino, CA', 902000.0),
#  ('Staten Island, NY', 48000.0),
#  ('Newport News, VA', 43000.0),
#  ('Sunnyvale, CA', 1042000.0),
#  ('New York, NY', 13594000.0),
#  ('Novato, CA', 82000.0),
#  ('Florham Park, NJ', 393000.0),
#  ('Kirkland, WA', 110000.0),
#  ('Woodridge, IL', 115000.0),
#  ('Mooresville, NC', 276000.0),
#  ('Reedley, CA', 47000.0),
#  ('East Palo Alto, CA', 51000.0),
#  ('Pasadena, TX', 47000.0),
#  ('Jersey City, NJ', 1422000.0),
#  ('Union City, CA', 167000.0),
#  ('Louisville, CO', 163000.0),
#  ('Exton, PA', 38000.0),
#  ('Los Angeles, CA', 3021000.0),
#  ('Camden, NJ', 146000.0),
#  ('Westlake, TX', 92000.0),
#  ('West Orange, NJ', 98000.0),
#  ('Huntersville, NC', 214000.0),
#  ('Fort Worth, TX', 547000.0),
#  ('Marina del Rey, CA', 107000.0),
#  ('San Ramon, CA', 158000.0),
#  ('Phoenix, AZ', 1465000.0),
#  ('South Plainfield, NJ', 27000.0),
#  ('Fort Eustis, VA', 49000.0),
#  ('Menlo Park, CA', 697000.0),
#  ('Newtown Square, PA', 64000.0),
#  ('West Chester, PA', 74000.0),
#  ('Henderson, CO', 57000.0),
#  ('Suffolk, VA', 43000.0),
#  ('Norfolk, VA', 699000.0),
#  ('San Francisco, CA', 7017000.0),
#  ('Dublin, OH', 56000.0),
#  ('Brooklyn, NY', 292000.0),
#  ('Chester Township, PA', 37000.0),
#  ('Venice, CA', 94000.0),
#  ('Charlotte, NC', 3264000.0),
#  ('Woodbridge, NJ', 98000.0),
#  ('Lone Tree, CO', 49000.0),
#  ('Northbrook, IL', 151000.0),
#  ('Chicago, IL', 7119000.0),
#  ('Virginia Beach, VA', 43000.0),
#  ('Azusa, CA', 65000.0),
#  ('Greenwood Village, Arapahoe, CO', 383000.0),
#  ('Broomfield, CO', 397000.0),
#  ('San Rafael, CA', 104000.0),
#  ('Athens, GA', 128000.0),
#  ('South San Francisco, CA', 346000.0),
#  ('Summit, NJ', 100000.0),
#  ('Marlton, NJ', 114000.0),
#  ('Whippany, NJ', 98000.0),
#  ('Whitestown, IN', 34000.0),
#  ('Carmel, IN', 68000.0),
#  ('Los Gatos, CA', 268000.0),
#  ('Gardena, CA', 113000.0),
#  ('Fort Washington, PA', 41000.0),
#  ('Haworth, NJ', 127000.0),
#  ('Plymouth Meeting, PA', 105000.0),
#  ('West Point, PA', 128000.0),
#  ('Broadview, IL', 120000.0),
#  ('Alachua, FL', 30000.0),
#  ('Downers Grove, IL', 538000.0),
#  ('Fort Mill, SC', 107000.0),
#  ('Arlington Heights, IL', 68000.0),
#  ('Centennial, CO', 467000.0),
#  ('Newark, NJ', 349000.0),
#  ('American Fork, UT', 26000.0),
#  ('Farmers Branch, TX', 44000.0),
#  ('Hercules, CA', 65000.0),
#  ('Franklin Lakes, NJ', 27000.0),
#  ('Deerfield, IL', 232000.0),
#  ('Fremont, CA', 242000.0),
#  ('Jeffersonville, IN', 34000.0),
#  ('Inglewood, CA', 55000.0),
#  ('Columbus, OH', 670000.0),
#  ('Carrollton, TX', 44000.0),
#  ('Hampton, VA', 571000.0),
#  ('Sugar Land, TX', 148000.0),
#  ('Bridgeview, IL', 42000.0),
#  ('Beverly Hills, CA', 99000.0),
#  ('Mount Laurel, NJ', 138000.0),
#  ('Glendale, AZ', 139000.0),
#  ('Lawrence, IN', 34000.0),
#  ('Feasterville Trevose, PA', 82000.0),
#  ('Burlingame, KS', 36000.0),
#  ('Little Ferry, NJ', 41000.0),
#  ('City of Industry, CA', 178000.0),
#  ('Lehi, UT', 109000.0),
#  ('Elk Grove Village, IL', 97000.0),
#  ('Topeka, KS', 36000.0),
#  ('Stanford, CA', 207000.0),
#  ('Evanston, IL', 42000.0),
#  ('Hilliard, OH', 56000.0),
#  ('Marin City, CA', 93000.0),
#  ('Mesa, AZ', 91000.0),
#  ('Brea, CA', 148000.0),
#  ('Northridge, CA', 57000.0),
#  ('Plano, TX', 798000.0),
#  ('Chandler, AZ', 261000.0),
#  ('Lewisville, TX', 85000.0),
#  ('Smithfield, VA', 43000.0),
#  ('San Jose, CA', 2430000.0),
#  ('San Diego, CA', 3460000.0),
#  ('Pearland, TX', 298000.0),
#  ('Woodcliff Lake, NJ', 48000.0),
#  ('Whittier, CA', 113000.0),
#  ('West Jordan, UT', 26000.0),
#  ('Kent, WA', 145000.0),
#  ('Addison, TX', 41000.0),
#  ('Parsippany, NJ', 146000.0),
#  ('Millbrae, CA', 65000.0),
#  ('Redwood City, CA', 797000.0),
#  ('Pico Rivera, CA', 113000.0),
#  ('Woodland Hills, CA', 488000.0),
#  ('Long Beach, CA', 711000.0),
#  ('Secaucus, NJ', 77000.0),
#  ('Lakewood, CO', 269000.0),
#  ('Allegheny West, PA', 87000.0),
#  ('Malvern, PA', 244000.0),
#  ('Northlake, IL', 67000.0),
#  ('Irving, TX', 976000.0),
#  ('Daly City, CA', 93000.0),
#  ('Issaquah, WA', 125000.0),
#  ('Arlington, TX', 303000.0),
#  ('DC Ranch, AZ', 88000.0),
#  ('Cerritos, CA', 144000.0),
#  ('Westerville, OH', 74000.0),
#  ('Pasadena, CA', 193000.0),
#  ('San Mateo, CA', 1011000.0),
#  ('Maywood, IL', 97000.0),
#  ('Irwindale, CA', 94000.0),
#  ('Aurora, CO', 192000.0),
#  ('Mount Vernon, NY', 42000.0),
#  ('Glendale, CA', 301000.0),
#  ('Bronx, NY', 89000.0),
#  ('Oak Brook, IL', 84000.0),
#  ('Austin, TX', 3103000.0),
#  ('Moorestown, NJ', 50000.0),
#  ('Iselin, NJ', 48000.0),
#  ('Itasca, IL', 67000.0),
#  ('Portsmouth, VA', 172000.0),
#  ('Hoboken, NJ', 98000.0),
#  ('Tempe, AZ', 1131000.0),
#  ('El Segundo, CA', 786000.0),
#  ('Essex Fells, NJ', 27000.0),
#  ('Renton, WA', 55000.0),
#  ('Rolling Meadows, IL', 67000.0),
#  ('Stafford, TX', 58000.0),
#  ('Wilmington, DE', 391000.0),
#  ('Seattle, WA', 840000.0),
#  ('Alhambra, CA', 65000.0),
#  ('Berwyn, PA', 87000.0)]

# %%
result = []
for i in min_by_location:
    min_by_location_dict = {}
    min_by_location_dict["city-state"] = i[0]
    min_by_location_dict["The lowest min"] = i[1]
    result.append(min_by_location)

return jsonify(result)
# Out:
#   File "<ipython-input-10-1a01f689da7d>", line 8
#     return jsonify(result)
#     ^
# SyntaxError: 'return' outside function

# %%
# #Extract CSV into DataFrame
# data_analyst_df = pd.read_csv("../data/clean_data_analyst.csv")
# data_analyst_df.iloc[0:]

# %%
# #Create Database connection
# connection_string = "postgres:Jpm!1990@localhost:5432/da_job"
# engine = create_engine(f'postgresql://{connection_string}')

# %%
# engine.table_names()

# %%
# Base=automap_base()
# Base.prepare(engine,reflect=True)
# Base.classes.keys()

# %%
# job=Base.classes.test_limited_columns

# %%
# session=Session(engine)

# %%
# session.query(job.id).all()

# %%
# #Use pandas to Load  csv converted DataFrames into database
# data_analyst_df.to_json('data_analyst_json', con=engine, if_exists='append', index=False)

# %%
# #confirm data has been added by quering the table
# pd.read_sql_query('select * from data_analyst', con=engine).head()

# %%
# data_analyst_df.to_json("jsonfile.json",orient='records')
